# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f1_scores = {
    "ViT": {
        '0': 0.7665,
        '1': 0.8449,
        '2': 0.6923,
        '3': 0.8916,
        '4': 0.5667,
        '5': 0.8393,
        '6': 0.8506,
        '7': 0.6136,
        '8': 0.9640
    },
    'XGBoost': {
        '0': 0.78,
        '1': 0.89,
        '2': 0.71,
        '3': 0.92,
        '4': 0.57,
        '5': 0.76,
        '6': 0.94,
        '7': 0.70,
        '8': 0.93
    },
    'EfficientNet': {
        '0': 0.7459,
        '1': 0.8681,
        '2': 0.7800,
        '3': 0.7561,
        '4': 0.6769,
        '5': 0.7967,
        '6': 0.9195,
        '7': 0.6296,
        '8': 0.9241
    },
    'ConvNext': {
        '0': 0.76,
        '1': 0.93,
        '2': 0.77,
        '3': 0.90,
        '4': 0.69,
        '5': 0.83,
        '6': 0.93,
        '7': 0.72,
        '8': 1.00
    },
}

# %%
df = pd.DataFrame(f1_scores)

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(df, annot=False, cmap="coolwarm", linewidths=0.5, cbar=True)

# Ajouter manuellement les valeurs
for i in range(df.shape[0]):  # Parcours des lignes
    for j in range(df.shape[1]):  # Parcours des colonnes
        text = f"{df.iloc[i, j]:.2f}"
        ax.text(j + 0.5, i + 0.5, text, ha="center", va="center", color="black")

plt.title("F1-score par classe et modèle")
plt.xlabel("Modèles")
plt.ylabel("Classes")

plt.show()

# %% [markdown]
# ## Labellisé

# %%
f1_scores = {
    "ViT": {
        '0': 0.7797,
        '1': 0.8663,
        '2': 0.7158,
        '3': 0.8706,
        '4': 0.4615,
        '5': 0.8235,
        '6': 0.8293,
        '7': 0.6813,
        '8': 0.9635
    },   
    "XGBoost": {
        '0': 0.78,
        '1': 0.86,
        '2': 0.74,
        '3': 0.88,
        '4': 0.64,
        '5': 0.75,
        '6': 0.93,
        '7': 0.67,
        '8': 0.98
    },
    'EfficientNet': {
        '0': 0.7046,
        '1': 0.8770,
        '2': 0.7742,
        '3': 0.8095,
        '4': 0.5676,
        '5': 0.7642,
        '6': 0.8936,
        '7': 0.6067,
        '8': 0.8951
    },
    'ConvNext': {
        '0': 0.84,
        '1': 0.90,
        '2': 0.81,
        '3': 0.88,
        '4': 0.69,
        '5': 0.91,
        '6': 0.91,
        '7': 0.81,
        '8': 1.00
    },
}

# %%
df = pd.DataFrame(f1_scores)

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(df, annot=False, cmap="coolwarm", linewidths=0.5, cbar=True)

# Ajouter manuellement les valeurs
for i in range(df.shape[0]):  # Parcours des lignes
    for j in range(df.shape[1]):  # Parcours des colonnes
        text = f"{df.iloc[i, j]:.2f}"
        ax.text(j + 0.5, i + 0.5, text, ha="center", va="center", color="black")

plt.title("F1-score par classe et modèle")
plt.xlabel("Modèles")
plt.ylabel("Classes")

plt.show()
